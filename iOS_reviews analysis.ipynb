# %%
import nltk
import string
import spacy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk import *
from nltk.corpus import stopwords
from wordcloud import WordCloud
from app_store_scraper import AppStore

# %%
# 1. Scrape the reviews from App Store
cdg = AppStore(country='sg', app_name='cdg-zig', app_id='954951647')
cdg.review(how_many=25000)
# Out:
# 2022-08-15 15:12:38,911 [INFO] Base - Initialised: AppStore('sg', 'cdg-zig', 954951647)
# 2022-08-15 15:12:38,912 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/cdg-zig/id954951647
# 2022-08-15 15:12:44,039 [INFO] Base - [id:954951647] Fetched 360 reviews (360 fetched in total)
# 2022-08-15 15:12:49,568 [INFO] Base - [id:954951647] Fetched 660 reviews (660 fetched in total)
# 2022-08-15 15:12:54,926 [INFO] Base - [id:954951647] Fetched 1000 reviews (1000 fetched in total)
# 2022-08-15 15:13:00,218 [INFO] Base - [id:954951647] Fetched 1380 reviews (1380 fetched in total)
# 2022-08-15 15:13:05,690 [INFO] Base - [id:954951647] Fetched 1740 reviews (1740 fetched in total)
# 2022-08-15 15:13:08,618 [INFO] Base - [id:954951647] Fetched 1937 reviews (1937 fetched in total)

# %%
reviews = pd.DataFrame(np.array(cdg.reviews), columns=['review'])
ios_reviews = reviews.join(pd.DataFrame(reviews.pop('review').tolist()))
df_ios_reviews = ios_reviews.sort_values(by='date', ascending=False)
df_ios_reviews
# Out:
#                                       developerResponse  \
# 199                                                 NaN
# 403                                                 NaN
# 201                                                 NaN
# 213                                                 NaN
# 268   {'id': 31410931, 'body': 'Dear Sir/Mdm, thank ...
# ...                                                 ...
# 1560                                                NaN
# 1237                                                NaN
# 1700                                                NaN
# 883                                                 NaN
# 570                                                 NaN
#
#                                      title  \
# 199         Doesn’t let me enter locations
# 403                       Paylah deduction
# 201                         Great Taxi App
# 213                        App not working
# 268               Apps is not friendly use
# ...                                    ...
# 1560                            Great App!
# 1237                  Recommended taxi app
# 1700         New ComfortDelgro Booking App
# 883                              Great app
# 570   I glad to see a new app from comfort
#
#                                                  review  rating  \
# 199   When I try to choose a new destination, the ap...       2
# 403   Money was deducted from my paylah even though ...       1
# 201   Book with ease at reasonable taxi rates and co...       4
# 213   Not able to click done. Seems like the done bu...       1
# 268   I want to change my old email for my receipt, ...       1
# ...                                                 ...     ...
# 1560              Love it, good job and pls keep it up!       5
# 1237                      The way taxi apps should be:)       5
# 1700                                         Awesome...       5
# 883   Faster, more stable, quite surprise when it sh...       5
# 570   So happen to see this app and downloaded the a...       5
#
#                       userName                date  isEdited
# 199                    hagha12 2022-08-13 08:15:21     False
# 403                 newbie6157 2022-08-13 05:07:20     False
# 201                     jangwl 2022-08-13 03:53:05     False
# 213               Reviewer4:35 2022-08-11 03:05:47     False
# 268                  ttobingth 2022-08-10 05:36:31     False
# ...                        ...                 ...       ...
# 1560              Derrick Chua 2015-01-21 01:14:19     False
# 1237  The eternal optimist-TEO 2015-01-20 13:30:50     False
# 1700             clydewong hui 2015-01-20 08:03:26     False
# 883                 Keith.dinh 2015-01-20 00:01:02     False
# 570               Nickytheuser 2015-01-19 09:34:59     False
#
# [1937 rows x 7 columns]

# %%
review_content_rating = df_ios_reviews[['title', 'review', 'rating', 'date']]
review_content_rating.head()
# Out:
#                               title  \
# 199  Doesn’t let me enter locations
# 403                Paylah deduction
# 201                  Great Taxi App
# 213                 App not working
# 268        Apps is not friendly use
#
#                                                 review  rating  \
# 199  When I try to choose a new destination, the ap...       2
# 403  Money was deducted from my paylah even though ...       1
# 201  Book with ease at reasonable taxi rates and co...       4
# 213  Not able to click done. Seems like the done bu...       1
# 268  I want to change my old email for my receipt, ...       1
#
#                    date
# 199 2022-08-13 08:15:21
# 403 2022-08-13 05:07:20
# 201 2022-08-13 03:53:05
# 213 2022-08-11 03:05:47
# 268 2022-08-10 05:36:31

# %%
# review_content_rating['Summary_of_Issues'] = review_content_rating['title'].str.cat(review_content_rating['review'], sep='-')
review_content_rating['Summary_of_Issues'] = review_content_rating['review']
review_content_rating.head()
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_76105/2252479442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_content_rating['Summary_of_Issues'] = review_content_rating['review']
#                                      title  \
# 199         Doesn’t let me enter locations
# 403                       Paylah deduction
# 201                         Great Taxi App
# 213                        App not working
# 268               Apps is not friendly use
# ...                                    ...
# 1560                            Great App!
# 1237                  Recommended taxi app
# 1700         New ComfortDelgro Booking App
# 883                              Great app
# 570   I glad to see a new app from comfort
#
#                                                  review  rating  \
# 199   When I try to choose a new destination, the ap...       2
# 403   Money was deducted from my paylah even though ...       1
# 201   Book with ease at reasonable taxi rates and co...       4
# 213   Not able to click done. Seems like the done bu...       1
# 268   I want to change my old email for my receipt, ...       1
# ...                                                 ...     ...
# 1560              Love it, good job and pls keep it up!       5
# 1237                      The way taxi apps should be:)       5
# 1700                                         Awesome...       5
# 883   Faster, more stable, quite surprise when it sh...       5
# 570   So happen to see this app and downloaded the a...       5
#
#                     date                                  Summary_of_Issues
# 199  2022-08-13 08:15:21  When I try to choose a new destination, the ap...
# 403  2022-08-13 05:07:20  Money was deducted from my paylah even though ...
# 201  2022-08-13 03:53:05  Book with ease at reasonable taxi rates and co...
# 213  2022-08-11 03:05:47  Not able to click done. Seems like the done bu...
# 268  2022-08-10 05:36:31  I want to change my old email for my receipt, ...
# ...                  ...                                                ...
# 1560 2015-01-21 01:14:19              Love it, good job and pls keep it up!
# 1237 2015-01-20 13:30:50                      The way taxi apps should be:)
# 1700 2015-01-20 08:03:26                                         Awesome...
# 883  2015-01-20 00:01:02  Faster, more stable, quite surprise when it sh...
# 570  2015-01-19 09:34:59  So happen to see this app and downloaded the a...
#
# [1937 rows x 5 columns]

# %%
# 2. Filter date starting from '2022-05-01'
review_content_rating['date'] = pd.to_datetime(review_content_rating['date'], "%Y-%m-%d").dt.date
review_content_rating = review_content_rating.set_index('date')

startdate = pd.to_datetime("2022-5-1").date()

filter_reviews = review_content_rating.loc[:startdate]
filter_reviews.tail()
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/544544632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_content_rating['date'] = pd.to_datetime(review_content_rating['date'], "%Y-%m-%d").dt.date
#                                       title  \
# date
# 2022-05-04                          Useless
# 2022-05-04  App not working as it should be
# 2022-05-03                         Kosh Yeo
# 2022-05-03                      stupid name
# 2022-05-02       Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues
# date
# 2022-05-04  So many taxi in singapore also hard to get tax...
# 2022-05-04  This App is bad compared to the old Comfort ap...
# 2022-05-03                     Very good apps more to improve
# 2022-05-03  guys … brainstorming session…. we need a name ...
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...

# %%
# 3. Add 'positive/negative' label
df = filter_reviews

# Rating/Score 1-4: negative, rating/score 5: positive
def label_func(rating):
    if rating <= 4:
        return 'negative'
    else:
        return 'positive'
    
df['Label'] = df['rating'].apply(label_func)
df
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/4217939640.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Label'] = df['rating'].apply(label_func)
#                                                title  \
# date
# 2022-08-09                       Chase to the bottom
# 2022-08-07                  Auto cancelled by itself
# 2022-08-07                       Not friendly to use
# 2022-08-06  Cannot view text while typing feedback !
# 2022-08-06                                 Lousy App
# ...                                              ...
# 2022-05-04                                   Useless
# 2022-05-04           App not working as it should be
# 2022-05-03                                  Kosh Yeo
# 2022-05-03                               stupid name
# 2022-05-02                Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-08-09  Your service and your app are consistently deg...       1
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...       1
# 2022-08-07  Tried to book but couldn’t do advance booking ...       1
# 2022-08-06  The app has a feedback section but it’s comple...       2
# 2022-08-06  Deleted and re-download App numerous times, st...       1
# ...                                                       ...     ...
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues     Label
# date
# 2022-08-09  Your service and your app are consistently deg...  negative
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...  negative
# 2022-08-07  Tried to book but couldn’t do advance booking ...  negative
# 2022-08-06  The app has a feedback section but it’s comple...  negative
# 2022-08-06  Deleted and re-download App numerous times, st...  negative
# ...                                                       ...       ...
# 2022-05-04  So many taxi in singapore also hard to get tax...  negative
# 2022-05-04  This App is bad compared to the old Comfort ap...  negative
# 2022-05-03                     Very good apps more to improve  positive
# 2022-05-03  guys … brainstorming session…. we need a name ...  negative
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...  negative
#
# [183 rows x 5 columns]

# %%
# 4. Data Cleaning 

# 4-1) Convert words into lowercase

df["Summary_of_Issues"] = df["Summary_of_Issues"].str.lower() 

df
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/3734962086.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Summary_of_Issues"] = df["Summary_of_Issues"].str.lower()
#                                                title  \
# date
# 2022-08-09                       Chase to the bottom
# 2022-08-07                  Auto cancelled by itself
# 2022-08-07                       Not friendly to use
# 2022-08-06  Cannot view text while typing feedback !
# 2022-08-06                                 Lousy App
# ...                                              ...
# 2022-05-04                                   Useless
# 2022-05-04           App not working as it should be
# 2022-05-03                                  Kosh Yeo
# 2022-05-03                               stupid name
# 2022-05-02                Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-08-09  Your service and your app are consistently deg...       1
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...       1
# 2022-08-07  Tried to book but couldn’t do advance booking ...       1
# 2022-08-06  The app has a feedback section but it’s comple...       2
# 2022-08-06  Deleted and re-download App numerous times, st...       1
# ...                                                       ...     ...
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues     Label
# date
# 2022-08-09  your service and your app are consistently deg...  negative
# 2022-08-07  pls fix the apps. this is the 2nd time i booke...  negative
# 2022-08-07  tried to book but couldn’t do advance booking ...  negative
# 2022-08-06  the app has a feedback section but it’s comple...  negative
# 2022-08-06  deleted and re-download app numerous times, st...  negative
# ...                                                       ...       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...  negative
# 2022-05-04  this app is bad compared to the old comfort ap...  negative
# 2022-05-03                     very good apps more to improve  positive
# 2022-05-03  guys … brainstorming session…. we need a name ...  negative
# 2022-05-02  it’s a shame to change logo to z. \nrussian tr...  negative
#
# [183 rows x 5 columns]

# %%
# 4-2) Remove number and punctuation mark
df['Cleaned_reviews'] = df['Summary_of_Issues'].str.replace(r'[^\w\s]+', ' ')
df['Cleaned_reviews'] = df['Cleaned_reviews'].str.replace('\d+', ' ')
df
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1974911576.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Cleaned_reviews'] = df['Summary_of_Issues'].str.replace(r'[^\w\s]+', ' ')
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1974911576.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cleaned_reviews'] = df['Summary_of_Issues'].str.replace(r'[^\w\s]+', ' ')
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1974911576.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Cleaned_reviews'] = df['Cleaned_reviews'].str.replace('\d+', ' ')
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1974911576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cleaned_reviews'] = df['Cleaned_reviews'].str.replace('\d+', ' ')
#                                                title  \
# date
# 2022-08-09                       Chase to the bottom
# 2022-08-07                  Auto cancelled by itself
# 2022-08-07                       Not friendly to use
# 2022-08-06  Cannot view text while typing feedback !
# 2022-08-06                                 Lousy App
# ...                                              ...
# 2022-05-04                                   Useless
# 2022-05-04           App not working as it should be
# 2022-05-03                                  Kosh Yeo
# 2022-05-03                               stupid name
# 2022-05-02                Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-08-09  Your service and your app are consistently deg...       1
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...       1
# 2022-08-07  Tried to book but couldn’t do advance booking ...       1
# 2022-08-06  The app has a feedback section but it’s comple...       2
# 2022-08-06  Deleted and re-download App numerous times, st...       1
# ...                                                       ...     ...
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues     Label  \
# date
# 2022-08-09  your service and your app are consistently deg...  negative
# 2022-08-07  pls fix the apps. this is the 2nd time i booke...  negative
# 2022-08-07  tried to book but couldn’t do advance booking ...  negative
# 2022-08-06  the app has a feedback section but it’s comple...  negative
# 2022-08-06  deleted and re-download app numerous times, st...  negative
# ...                                                       ...       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...  negative
# 2022-05-04  this app is bad compared to the old comfort ap...  negative
# 2022-05-03                     very good apps more to improve  positive
# 2022-05-03  guys … brainstorming session…. we need a name ...  negative
# 2022-05-02  it’s a shame to change logo to z. \nrussian tr...  negative
#
#                                               Cleaned_reviews
# date
# 2022-08-09  your service and your app are consistently deg...
# 2022-08-07  pls fix the apps  this is the  nd time i booke...
# 2022-08-07  tried to book but couldn t do advance booking ...
# 2022-08-06  the app has a feedback section but it s comple...
# 2022-08-06  deleted and re download app numerous times  st...
# ...                                                       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...
# 2022-05-04  this app is bad compared to the old comfort ap...
# 2022-05-03                     very good apps more to improve
# 2022-05-03  guys   brainstorming session  we need a name f...
# 2022-05-02  it s a shame to change logo to z  \nrussian tr...
#
# [183 rows x 6 columns]

# %%
# 4-3) Word tokenization
df['tokenized_reviews'] = df.apply(lambda row: nltk.word_tokenize(row['Cleaned_reviews']), axis=1)
df
 
# Length of reviews
df['reviews_length'] = df.apply(lambda row: len(row['tokenized_reviews']), axis=1)
df
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1620069006.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokenized_reviews'] = df.apply(lambda row: nltk.word_tokenize(row['Cleaned_reviews']), axis=1)
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/1620069006.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews_length'] = df.apply(lambda row: len(row['tokenized_reviews']), axis=1)
#                                                title  \
# date
# 2022-08-09                       Chase to the bottom
# 2022-08-07                  Auto cancelled by itself
# 2022-08-07                       Not friendly to use
# 2022-08-06  Cannot view text while typing feedback !
# 2022-08-06                                 Lousy App
# ...                                              ...
# 2022-05-04                                   Useless
# 2022-05-04           App not working as it should be
# 2022-05-03                                  Kosh Yeo
# 2022-05-03                               stupid name
# 2022-05-02                Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-08-09  Your service and your app are consistently deg...       1
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...       1
# 2022-08-07  Tried to book but couldn’t do advance booking ...       1
# 2022-08-06  The app has a feedback section but it’s comple...       2
# 2022-08-06  Deleted and re-download App numerous times, st...       1
# ...                                                       ...     ...
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues     Label  \
# date
# 2022-08-09  your service and your app are consistently deg...  negative
# 2022-08-07  pls fix the apps. this is the 2nd time i booke...  negative
# 2022-08-07  tried to book but couldn’t do advance booking ...  negative
# 2022-08-06  the app has a feedback section but it’s comple...  negative
# 2022-08-06  deleted and re-download app numerous times, st...  negative
# ...                                                       ...       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...  negative
# 2022-05-04  this app is bad compared to the old comfort ap...  negative
# 2022-05-03                     very good apps more to improve  positive
# 2022-05-03  guys … brainstorming session…. we need a name ...  negative
# 2022-05-02  it’s a shame to change logo to z. \nrussian tr...  negative
#
#                                               Cleaned_reviews  \
# date
# 2022-08-09  your service and your app are consistently deg...
# 2022-08-07  pls fix the apps  this is the  nd time i booke...
# 2022-08-07  tried to book but couldn t do advance booking ...
# 2022-08-06  the app has a feedback section but it s comple...
# 2022-08-06  deleted and re download app numerous times  st...
# ...                                                       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...
# 2022-05-04  this app is bad compared to the old comfort ap...
# 2022-05-03                     very good apps more to improve
# 2022-05-03  guys   brainstorming session  we need a name f...
# 2022-05-02  it s a shame to change logo to z  \nrussian tr...
#
#                                             tokenized_reviews  reviews_length
# date
# 2022-08-09  [your, service, and, your, app, are, consisten...              47
# 2022-08-07  [pls, fix, the, apps, this, is, the, nd, time,...              46
# 2022-08-07  [tried, to, book, but, couldn, t, do, advance,...              37
# 2022-08-06  [the, app, has, a, feedback, section, but, it,...              26
# 2022-08-06  [deleted, and, re, download, app, numerous, ti...              28
# ...                                                       ...             ...
# 2022-05-04  [so, many, taxi, in, singapore, also, hard, to...              23
# 2022-05-04  [this, app, is, bad, compared, to, the, old, c...             167
# 2022-05-03              [very, good, apps, more, to, improve]               6
# 2022-05-03  [guys, brainstorming, session, we, need, a, na...              55
# 2022-05-02  [it, s, a, shame, to, change, logo, to, z, rus...              23
#
# [183 rows x 8 columns]

# %%
# 4-4) Remove stopwords

def remove_english_stopwords_func(text):
    t = [token for token in text if token.lower() not in stopwords.words("english")]
    text = ' '.join(t)
    return text


df['Nostopwords_reviews'] = df['tokenized_reviews'].apply(remove_english_stopwords_func)
df
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/3914445207.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nostopwords_reviews'] = df['tokenized_reviews'].apply(remove_english_stopwords_func)
#                                                title  \
# date
# 2022-08-09                       Chase to the bottom
# 2022-08-07                  Auto cancelled by itself
# 2022-08-07                       Not friendly to use
# 2022-08-06  Cannot view text while typing feedback !
# 2022-08-06                                 Lousy App
# ...                                              ...
# 2022-05-04                                   Useless
# 2022-05-04           App not working as it should be
# 2022-05-03                                  Kosh Yeo
# 2022-05-03                               stupid name
# 2022-05-02                Disappointed with new logo
#
#                                                        review  rating  \
# date
# 2022-08-09  Your service and your app are consistently deg...       1
# 2022-08-07  Pls fix the apps. This is the 2nd time I booke...       1
# 2022-08-07  Tried to book but couldn’t do advance booking ...       1
# 2022-08-06  The app has a feedback section but it’s comple...       2
# 2022-08-06  Deleted and re-download App numerous times, st...       1
# ...                                                       ...     ...
# 2022-05-04  So many taxi in singapore also hard to get tax...       1
# 2022-05-04  This App is bad compared to the old Comfort ap...       2
# 2022-05-03                     Very good apps more to improve       5
# 2022-05-03  guys … brainstorming session…. we need a name ...       2
# 2022-05-02  It’s a shame to change logo to z. \nRussian tr...       1
#
#                                             Summary_of_Issues     Label  \
# date
# 2022-08-09  your service and your app are consistently deg...  negative
# 2022-08-07  pls fix the apps. this is the 2nd time i booke...  negative
# 2022-08-07  tried to book but couldn’t do advance booking ...  negative
# 2022-08-06  the app has a feedback section but it’s comple...  negative
# 2022-08-06  deleted and re-download app numerous times, st...  negative
# ...                                                       ...       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...  negative
# 2022-05-04  this app is bad compared to the old comfort ap...  negative
# 2022-05-03                     very good apps more to improve  positive
# 2022-05-03  guys … brainstorming session…. we need a name ...  negative
# 2022-05-02  it’s a shame to change logo to z. \nrussian tr...  negative
#
#                                               Cleaned_reviews  \
# date
# 2022-08-09  your service and your app are consistently deg...
# 2022-08-07  pls fix the apps  this is the  nd time i booke...
# 2022-08-07  tried to book but couldn t do advance booking ...
# 2022-08-06  the app has a feedback section but it s comple...
# 2022-08-06  deleted and re download app numerous times  st...
# ...                                                       ...
# 2022-05-04  so many taxi in singapore also hard to get tax...
# 2022-05-04  this app is bad compared to the old comfort ap...
# 2022-05-03                     very good apps more to improve
# 2022-05-03  guys   brainstorming session  we need a name f...
# 2022-05-02  it s a shame to change logo to z  \nrussian tr...
#
#                                             tokenized_reviews  reviews_length  \
# date
# 2022-08-09  [your, service, and, your, app, are, consisten...              47
# 2022-08-07  [pls, fix, the, apps, this, is, the, nd, time,...              46
# 2022-08-07  [tried, to, book, but, couldn, t, do, advance,...              37
# 2022-08-06  [the, app, has, a, feedback, section, but, it,...              26
# 2022-08-06  [deleted, and, re, download, app, numerous, ti...              28
# ...                                                       ...             ...
# 2022-05-04  [so, many, taxi, in, singapore, also, hard, to...              23
# 2022-05-04  [this, app, is, bad, compared, to, the, old, c...             167
# 2022-05-03              [very, good, apps, more, to, improve]               6
# 2022-05-03  [guys, brainstorming, session, we, need, a, na...              55
# 2022-05-02  [it, s, a, shame, to, change, logo, to, z, rus...              23
#
#                                           Nostopwords_reviews
# date
# 2022-08-09  service app consistently degrading app constan...
# 2022-08-07  pls fix apps nd time booked taxi auto cancelle...
# 2022-08-07  tried book advance booking days ahead yet driv...
# 2022-08-06  app feedback section completely covered keyboa...
# 2022-08-06  deleted download app numerous times still show...
# ...                                                       ...
# 2022-05-04  many taxi singapore also hard get taxi later c...
# 2022-05-04  app bad compared old comfort app twice encount...
# 2022-05-03                                  good apps improve
# 2022-05-03  guys brainstorming session need name comfort t...
# 2022-05-02  shame change logo z russian troops use sign ki...
#
# [183 rows x 9 columns]

# %%
# 4-5) Devided by label
positive_review = df[(df['Label'] == 'positive')]['Nostopwords_reviews']
negative_review = df[(df['Label'] == 'negative')]['Nostopwords_reviews']

# %%
# 5. Normalise word (reduce words to root or root form)

def norm_lemm_v_a_n_r_func(text):
    words1 = word_tokenize(text)
    text1 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='v') for word in words1])
    words2 = word_tokenize(text1)
    text2 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='a') for word in words2])
    words3 = word_tokenize(text2)
    text3 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='n') for word in words3])
    words4 = word_tokenize(text3)
    text4 = ' '.join([WordNetLemmatizer().lemmatize(word, pos='r') for word in words4])
    return text4

# Normalize the whole reviews
Nostopwords_reviews = df['Nostopwords_reviews'].str.cat(sep=' ')
Normalized_review = norm_lemm_v_a_n_r_func(Nostopwords_reviews)

# Normalize postive reviews
text_corpus_positive_review = positive_review.str.cat(sep=' ')
Normalized_positive_review = norm_lemm_v_a_n_r_func(text_corpus_positive_review)

# Normalize negative reviews
text_corpus_negative_review = negative_review.str.cat(sep=' ')
Normalized_negative_review = norm_lemm_v_a_n_r_func(text_corpus_negative_review)

# %%
# 6. Remove specific words
def multiple_word_remove_func(text, words_remove_list):
    words_to_remove_list = words_remove_list
    words = word_tokenize(text)
    text = ' '.join([word for word in words if word not in words_to_remove_list])
    return text

words_remove_list = ['app', 'apps', 'booking', 'cab', 'taxi', 'book', 'cdg', 'one', 'even', 'take', 'many', 'get', 'also', 'go', 'make', 'still', 'use', 'keep', 'please', 'try', 'always', 'find', 'say', 'need']

# 6-1) Remove specific words from the whole reviews
remove_word_review = multiple_word_remove_func(Normalized_review, words_remove_list)
remove_word_review
# Out:
# 'service consistently degrade constantly crash assign know nothing assignment company singapore could proud second rate operation become disillusion pls fix nd time auto cancel reason receive sm min driver call inform arrive show detail advance day ahead yet driver assign come pick current time advance cancel immediately feedback section completely cover keyboard type feedback see type delete download numerous time show type vehicle send email feedback nothing do great first recent update miss order drive away search never time till cancel hard full bug inconvenient u work parent drop kid school without add another destination time driver reprimand cause understand price different n really feel driver earn low covid period give accurate information useful area scan qr code street hail small hard aim sometimes select destination stick continue cancel search progress result min attempt two row cancel wait way reach front block waste min life addition feedback mechanism difficult iphone text box completely cover keyboard type submit button likewise impossible press lousy design real time location accurate minute away location driver tend drive u conveniently cancel especially peak hour seem greedy lockdown year enough grow humility humanity like others issue card payment buggy crash time time call bad response tada grab far none friend relative good exp driver first time pain setup driver super unprofessional know road closure u huge detour cost risk fare high ever since become zig bad constantly work last trip either show blank page server connection error end switch transport service provider ride within minute guy careful put card call available deduct money inside card nonsense compare previous compare like uber ard grab gojek comfort extremely consistent consistent failure regardless old current update reliable communicate lack communication prompt update realise pick location close reopen co hang problem think oh update yes frequent update terribly lack customer touchpoints hang hang eg wait circle spin idea happen wait min nothing hang eg put location choose mode transport message screen tell happen hang click anything close reopen wait min nothing hang eg manage tap choose mode transport hang message pls wait high traffic sorry hang eg stick blue screen zig extremely slow load page reliability work feel like hang often grab never hang may tell car never hang comfort rainy day right hang often work singapore visible big company spend money actual professional build sufficient support sufficient people test provide feedback ridiculous wait min finally load tell search tell available right early hang presumably handle high traffic empty time could reach destination could pick second passenger large company country right customer driver know min tell could train reach destination joke handle high traffic decide stop communication hang instead well do comfort well do choose incompetent creator service provider whatever else might pls fix cancel search close background car close multiple time see cancel bad ever never refresh nd time shxtty first time show search receive sm driver way pick never show close open bad bad laggy often alert eg car enroute car arrive main screen show search car today car arrive driver call come show car slow input response mean search address frustrate process attempt time car service good terrible connection server fail multiple time ride test phone connection fine bad experience rain server developer something time something wrong since month ago disappoint see comfort easy bad ever glitching refuse load update delete reinstall leave driver come back reload trip ongoing happen often stop bad great amaze driver identify location properly driver could see clark quay mrt station could locate stand crash upon launch reset reach user passenger location user idea location user already reset happen time unstable buggy map locator room improvement term user experience glitch charge card refund timely thou ...

# %%
# 6-2) Remove specific words from the positive reviews
remove_word_positive_review = multiple_word_remove_func(Normalized_positive_review , words_remove_list)
remove_word_positive_review
# Out:
# 'great amaze driver friendly kindly safety driver thank nice meet like much good able quick like allow change payment method add promo trip start allow comfort fleet experience driver destination without much hassle know singapore road heart rarely map know road le congest part day accordingly plan trip instinct travel cautious though thank milind fast efficient way easy improve provision information driver cancel trip could tell lot information situation private hire car prompt accept request rarely cancel experience wrt service nice wish would give promotion cod well far never receive power thank open tool good driver thank good improve'

# %%
# 6-3) Remove specific words from the negative reviews
remove_word_negative_review = multiple_word_remove_func(Normalized_negative_review, words_remove_list)
remove_word_negative_review
# Out:
# 'service consistently degrade constantly crash assign know nothing assignment company singapore could proud second rate operation become disillusion pls fix nd time auto cancel reason receive sm min driver call inform arrive show detail advance day ahead yet driver assign come pick current time advance cancel immediately feedback section completely cover keyboard type feedback see type delete download numerous time show type vehicle send email feedback nothing do great first recent update miss order drive away search never time till cancel hard full bug inconvenient u work parent drop kid school without add another destination time driver reprimand cause understand price different n really feel driver earn low covid period give accurate information useful area scan qr code street hail small hard aim sometimes select destination stick continue cancel search progress result min attempt two row cancel wait way reach front block waste min life addition feedback mechanism difficult iphone text box completely cover keyboard type submit button likewise impossible press lousy design real time location accurate minute away location driver tend drive u conveniently cancel especially peak hour seem greedy lockdown year enough grow humility humanity like others issue card payment buggy crash time time call bad response tada grab far none friend relative good exp driver first time pain setup driver super unprofessional know road closure u huge detour cost risk fare high ever since become zig bad constantly work last trip either show blank page server connection error end switch transport service provider ride within minute guy careful put card call available deduct money inside card nonsense compare previous compare like uber ard grab gojek comfort extremely consistent consistent failure regardless old current update reliable communicate lack communication prompt update realise pick location close reopen co hang problem think oh update yes frequent update terribly lack customer touchpoints hang hang eg wait circle spin idea happen wait min nothing hang eg put location choose mode transport message screen tell happen hang click anything close reopen wait min nothing hang eg manage tap choose mode transport hang message pls wait high traffic sorry hang eg stick blue screen zig extremely slow load page reliability work feel like hang often grab never hang may tell car never hang comfort rainy day right hang often work singapore visible big company spend money actual professional build sufficient support sufficient people test provide feedback ridiculous wait min finally load tell search tell available right early hang presumably handle high traffic empty time could reach destination could pick second passenger large company country right customer driver know min tell could train reach destination joke handle high traffic decide stop communication hang instead well do comfort well do choose incompetent creator service provider whatever else might pls fix cancel search close background car close multiple time see cancel bad ever never refresh nd time shxtty first time show search receive sm driver way pick never show close open bad bad laggy often alert eg car enroute car arrive main screen show search car today car arrive driver call come show car slow input response mean search address frustrate process attempt time car service good terrible connection server fail multiple time ride test phone connection fine bad experience rain server developer something time something wrong since month ago disappoint see comfort easy bad ever glitching refuse load update delete reinstall leave driver come back reload trip ongoing happen often stop bad identify location properly driver could see clark quay mrt station could locate stand crash upon launch reset reach user passenger location user idea location user already reset happen time unstable buggy map locator room improvement term user experience glitch charge card refund timely though contact customer ...

# %%
# 7. Count word frequency
def Word_frequency_func(text):
    words = word_tokenize(text)
    fdist = FreqDist(words) 
    df_fdist = pd.DataFrame({'Word': fdist.keys(),
                             'Word_frequency': fdist.values()})
    df_fdist = df_fdist.sort_values(by='Word_frequency', ascending=False)
    
    return df_fdist

# 7-1) Count word frequency for the whole reviews
df_Word_frequency = Word_frequency_func(remove_word_review)
df_Word_frequency.head(30)
# Out:
#            Word  Word_frequency
# 28       driver              67
# 21         time              47
# 59       update              40
# 186      server              33
# 23       cancel              32
# 208     comfort              32
# 32         show              28
# 135    location              27
# 114        wait              25
# 156         bad              24
# 223        hang              24
# 187  connection              24
# 29         call              23
# 72         work              22
# 188       error              20
# 292        open              19
# 27          min              19
# 440         new              18
# 39         pick              17
# 224     problem              17
# 344      charge              17
# 64       search              17
# 230    customer              17
# 193        ride              16
# 152       issue              15
# 254         car              14
# 396      change              14
# 0       service              14
# 180         zig              14
# 182        trip              14

# %%
# 7-2) Count word frequency for the postive reviews
df_positive_Word_frequency = Word_frequency_func(remove_word_positive_review)
df_positive_Word_frequency.head(30)
# Out:
#            Word  Word_frequency
# 2        driver               5
# 6         thank               4
# 11         good               3
# 20         trip               3
# 52       cancel               2
# 24   experience               2
# 30         road               2
# 32       rarely               2
# 14        allow               2
# 51  information               2
# 28         know               2
# 10         much               2
# 9          like               2
# 7          nice               2
# 49      improve               2
# 59          car               1
# 50    provision               1
# 53        could               1
# 54         tell               1
# 55          lot               1
# 56    situation               1
# 57      private               1
# 48         easy               1
# 58         hire               1
# 47          way               1
# 0         great               1
# 63          wrt               1
# 60       prompt               1
# 69          cod               1
# 75         open               1

# %%
# 7-3) Count word frequency for the negative review
df_negative_Word_frequency = Word_frequency_func(remove_word_negative_review)
df_negative_Word_frequency.head(30)
# Out:
#            Word  Word_frequency
# 28       driver              62
# 21         time              47
# 59       update              40
# 186      server              33
# 208     comfort              31
# 23       cancel              30
# 32         show              28
# 135    location              27
# 114        wait              25
# 187  connection              24
# 156         bad              24
# 223        hang              24
# 29         call              23
# 72         work              22
# 188       error              20
# 27          min              19
# 292        open              18
# 413         new              18
# 224     problem              17
# 230    customer              17
# 343      charge              17
# 39         pick              17
# 64       search              17
# 193        ride              16
# 152       issue              15
# 180         zig              14
# 48          see              13
# 153        card              13
# 403      change              13
# 0       service              13

# %%
# .8 Word cloud
def wordcloud_func(words):
    wordcloud = WordCloud(width = 3000, height = 3000,
                      background_color = 'white',
                      min_font_size = 10).generate(words)
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    
# 8-1) Word cloud for all reviews
all_review_wordcloud = wordcloud_func(remove_word_review)

# %%
# 8-2) Word cloud for positive reviews
positive_review_wordcloud = wordcloud_func(remove_word_positive_review)

# %%
# 8-3) Word cloud for negative reviews
negative_review_wordcloud = wordcloud_func(remove_word_negative_review)

# %%
# 9. Bar chart for word frequency
def word_freq_bar_func(X, Y, width, color, title):
    fig = plt.figure(figsize=(25, 15))
    fig.patch.set_facecolor('white')
    plt.bar(X, Y, 0.8, color = color)
    plt.xlabel('Words', fontsize=25)
    plt.ylabel('Word Frequency', fontsize=25)
    plt.suptitle("Frequency Distribution of the 30 most common iOS Reviews' Words", fontsize=35)
    plt.title(title, fontsize=30)
    
    # text annotation
    for a,b in zip(X, Y):
        plt.text(a, b+0.05, '%.0f' % b, ha='center', va='bottom', fontsize=20)
    
    # Change x_label's direction
    plt.tick_params(labelsize=20)
    plt.xticks(rotation=55) # Or change rotation=45 to rotation='vertical'
    plt.show()

# 9-1) Word frequency bar chart for all reviews
df_most_common_30_words = df_Word_frequency.head(30)
X1 = df_most_common_30_words['Word']
Y1 = df_most_common_30_words['Word_frequency']
color1 = '#0F52BA'
title1 = "All Reviews"
All_review_bar = word_freq_bar_func(X1, Y1, 0.8, color1, title1)

# %%
# 9-2) Word frequency bar chart for positive reviews
df_positive_most_30_common_words = Word_frequency_func(remove_word_positive_review).head(30)
X2 = df_positive_most_30_common_words['Word']
Y2 = df_positive_most_30_common_words['Word_frequency']
color2 = '#008080'
title2 = "Positive Reviews"
All_review_bar = word_freq_bar_func(X2, Y2, 0.8, color2, title2)

# %%
# 9-3) Word frequency bar chart for negative reviews
df_negative_most_30_common_words = Word_frequency_func(remove_word_negative_review).head(30)
X3 = df_negative_most_30_common_words['Word']
Y3 = df_negative_most_30_common_words['Word_frequency']
color3 = '#C41E3A'
title3 = "Negative Reviews"
All_review_bar = word_freq_bar_func(X3, Y3, 0.8, color3, title3)

# %%
# 10. Count the daily & total number for reviews
review_count = filter_reviews

# 10-1) Daily number for reviews
# 10-1-1) Daily number for all reviews
df_count_all_daily = pd.DataFrame({'Count_of_review':review_count.groupby(['date'])["Summary_of_Issues"].count()})
df_count_all_daily = df_count_all_daily.sort_values(by = 'date', ascending = False)
df_count_all_daily
# Out:
#             Count_of_review
# date
# 2022-08-09                1
# 2022-08-07                2
# 2022-08-06                3
# 2022-08-05                1
# 2022-08-04                1
# ...                     ...
# 2022-05-06                3
# 2022-05-05               10
# 2022-05-04                2
# 2022-05-03                2
# 2022-05-02                1
#
# [64 rows x 1 columns]

# %%
# 10-1-2) Daily number for positive/negative reviews
review_count['Label'] = review_count['rating'].apply(label_func)

df_count_label_daily = pd.DataFrame({'Count_of_review_label':review_count.groupby(['date','Label'])["Summary_of_Issues"].count()})
df_count_label_daily = df_count_label_daily.sort_values(by = 'date', ascending = False)
df_count_label_daily
# Out:
# /var/folders/vm/2qwzk39s5s5d1352z57dndwm0000gn/T/ipykernel_41882/2792099642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_count['Label'] = review_count['rating'].apply(label_func)
#                      Count_of_review_label
# date       Label
# 2022-08-09 negative                      1
# 2022-08-07 negative                      2
# 2022-08-06 negative                      3
# 2022-08-05 negative                      1
# 2022-08-04 negative                      1
# ...                                    ...
# 2022-05-05 positive                      1
# 2022-05-04 negative                      2
# 2022-05-03 positive                      1
#            negative                      1
# 2022-05-02 negative                      1
#
# [75 rows x 1 columns]

# %%
# 10-2) Total number for reviews
# 10-2-1) Total number for all reviews
df_count_all_total = pd.DataFrame({"Name":"All reviews",
                                   "Count_of_review":review_count['Summary_of_Issues'].count()}, index=[0])
df_count_all_total
# Out:
#           Name  Count_of_review
# 0  All reviews              183

# %%
# 10-2-2) Total number for positive/negative reviews
df_count_label_total = pd.DataFrame({'Count_of_label':review_count.groupby('Label')["Summary_of_Issues"].count()})
df_count_label_total
# Out:
#           Count_of_label
# Label
# negative             169
# positive              14

# %%
# 11. Count the daily & total number for star-rating (1-5)
# 11-1) Daily number for star-rating
df_count_rating_daily = pd.DataFrame({"Count_of_rating":review_count.groupby(['date', 'rating'])['Summary_of_Issues'].count()})
df_count_rating_daily = df_count_rating_daily.sort_values(by = 'date', ascending = False)
df_count_rating_daily
# Out:
#                    Count_of_rating
# date       rating
# 2022-08-09 1                     1
# 2022-08-07 1                     2
# 2022-08-06 2                     1
#            1                     2
# 2022-08-05 1                     1
# ...                            ...
# 2022-05-04 2                     1
#            1                     1
# 2022-05-03 5                     1
#            2                     1
# 2022-05-02 1                     1
#
# [93 rows x 1 columns]

# %%
# 11-2) Total number for star-rating
df_count_rating_total = pd.DataFrame({"Count_of_rating":review_count.groupby('rating')["Summary_of_Issues"].count()})
df_count_rating_total
# Out:
#         Count_of_rating
# rating
# 1                   136
# 2                    15
# 3                    13
# 4                     5
# 5                    14

# %%
# 12. Check review edited history
# df_count_user = pd.DataFrame({"count": df_ios_reviews.groupby('userName')['review'].count() })
# df_count_user = df_count_user.sort_values(by='count', ascending=False)
# df_count_user

df_ios_reviews.loc[df_ios_reviews['isEdited'] == True]
# Out:
#                                       developerResponse     userName  \
# 211   {'id': 28412094, 'body': 'Dear Sir/Mdm, we apo...     MaxFedUp
# 367   {'id': 19149981, 'body': 'Dear Sir/Mdm, we hav...    nyborjare
# 479   {'id': 24788204, 'body': 'Dear Sir/Mdm, thank ...        ywc22
# 186   {'id': 6405590, 'body': 'Dear Sir/Mdm, thank y...  Daniel Zeke
# 345   {'id': 23920015, 'body': 'Dear Sir/Mdm, we are...   Fiqyyyyyyy
# ...                                                 ...          ...
# 669   {'id': 6344931, 'body': 'Dear Sir/Mdm, thank y...     =abelle=
# 863   {'id': 6328848, 'body': 'Dear Sir/Mdm, thank y...    taiwancat
# 730   {'id': 6244579, 'body': 'Dear Sir/Mdm,  thank ...         Pyhs
# 1463  {'id': 6307305, 'body': 'Dear Sir/Mdm, thank y...  praches1031
# 1212  {'id': 6245060, 'body': 'Dear Sir/Mdm, thank y...       PQOJRS
#
#                     date                                       title  \
# 211  2022-05-10 23:04:47             Refresh App Makes No Difference
# 367  2022-05-07 07:52:01              Problem with server connection
# 479  2022-05-07 07:12:35                           App does not work
# 186  2022-05-07 07:12:31         What is going on?  Terrible upgrade
# 345  2022-05-04 23:43:32                                     Useless
# ...                  ...                                         ...
# 669  2018-12-14 03:05:58  HORRIBLE. just bring the old version BACK!
# 863  2018-12-12 23:41:12   poor user exp worse than previous version
# 730  2018-12-11 10:00:35               New app feels like a beta app
# 1463 2018-12-11 09:45:24                         New December update
# 1212 2018-12-10 07:55:39      New app cannot connect to Masterpass!!
#
#       isEdited                                             review  rating
# 211       True  Even with the refresh apps, it has not made an...       2
# 367       True  This is a frequent problem. Hope that it can b...       1
# 479       True                            Server connection issue       1
# 186       True  New app is TERRIBLE!  What happened?  Firstly,...       1
# 345       True  So many taxi in singapore also hard to get tax...       1
# ...        ...                                                ...     ...
# 669       True  i managed to start the app after deleting, res...       1
# 863       True  this new version has a lot of issues\n1. when ...       1
# 730       True  New app is very hard to navigate. The previous...       1
# 1463      True  The update released 9 hours ago on dec. 10th i...       1
# 1212      True  Disappointing..... please come up with a bette...       1
#
# [63 rows x 7 columns]
